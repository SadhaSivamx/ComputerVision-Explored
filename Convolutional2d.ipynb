# %%
def Convolutional2D(GImg):
  h=len(GImg)
  w=len(GImg[0])
  wn,hn=[0,0]
  #Setting New Image
  NewImg=[]
  for i in range(0,h-2,1):
    Hele=GImg[i:i+3]
    #Getting value after each convolutional operation
    Rele=[]
    for j in range(0,w-2,1):
      Rele.append(np.sum(np.matmul(Sobel,Hele[:,j:j+3])))
    #Adding To NewImg
    NewImg.append(Rele)
  return NewImg

# %%
import numpy as np
import cv2 as cv
import matplotlib.pyplot as plt
Img=cv.imread("Rott.png")
GrayImg=cv.cvtColor(Img, cv.COLOR_BGR2GRAY)
plt.imshow(GrayImg,cmap='gray')

# %%
Sobel=np.array([[1,0,-1],[2,0,-2],[1,0,-1]])
plt.imshow(Convolutional2D(GrayImg),cmap='gray')
